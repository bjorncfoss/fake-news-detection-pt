# %% [markdown]
# Notebook

# %%
import tensorflow as tf # 2.12
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 2
#       1 import tensorflow as tf # 2.12
# ----> 2 import torch
#
# File /usr/local/lib/python3.8/dist-packages/torch/__init__.py:229
#     227     if USE_GLOBAL_DEPS:
#     228         _load_global_deps()
# --> 229     from torch._C import *  # noqa: F403
#     231 # Appease the type checker; ordinarily this binding is inserted by the
#     232 # torch._C module initialization code in C
#     233 if TYPE_CHECKING:
#
# ImportError: /lib/aarch64-linux-gnu/libgomp.so.1: cannot allocate memory in static TLS block

# %%
gpu_available = tf.test.is_gpu_available()
is_cuda_gpu_available = tf.test.is_gpu_available(cuda_only=True)
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_413110/1738693072.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.

# %%
print(is_cuda_gpu_available)
# Out:
# True

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
